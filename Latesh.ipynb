# %% [markdown]
# <a href="https://colab.research.google.com/github/lateshkumar-creat/Module-1/blob/main/Latesh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello Lucky")
# Out:
# Hello Lucky
